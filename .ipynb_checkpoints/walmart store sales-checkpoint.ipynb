# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
features =pd.read_csv("features.csv")

# %%
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
stores = pd.read_csv("stores.csv")

# %%
stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
train = pd.read_csv("train.csv")

# %%
train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
test = pd.read_csv("test.csv")

# %%
test
# Out:
#         Store  Dept        Date  IsHoliday
# 0           1     1  2012-11-02      False
# 1           1     1  2012-11-09      False
# 2           1     1  2012-11-16      False
# 3           1     1  2012-11-23       True
# 4           1     1  2012-11-30      False
# ...       ...   ...         ...        ...
# 115059     45    98  2013-06-28      False
# 115060     45    98  2013-07-05      False
# 115061     45    98  2013-07-12      False
# 115062     45    98  2013-07-19      False
# 115063     45    98  2013-07-26      False
#
# [115064 rows x 4 columns]

# %%
#features and stores have a commom key 'Stores' and store in a variable features_store
features_store = features.merge(stores, how='inner', on='Store')

# %%
features_store.head(10)
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
# 5      1  2010-03-12        57.79       2.667        NaN        NaN
# 6      1  2010-03-19        54.58       2.720        NaN        NaN
# 7      1  2010-03-26        51.45       2.732        NaN        NaN
# 8      1  2010-04-02        62.27       2.719        NaN        NaN
# 9      1  2010-04-09        65.86       2.770        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type  \
# 0        NaN        NaN        NaN  211.096358         8.106      False    A
# ...

# %%
#types of dataframes
pd.DataFrame(features_store.dtypes, columns=['Type'])
# Out:
#                  Type
# Store           int64
# Date           object
# Temperature   float64
# Fuel_Price    float64
# MarkDown1     float64
# MarkDown2     float64
# MarkDown3     float64
# MarkDown4     float64
# MarkDown5     float64
# CPI           float64
# Unemployment  float64
# IsHoliday        bool
# Type           object
# Size            int64

# %%
# Date field has string type. We can convert them to datetime
train.head(8)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False
# 5      1     1  2010-03-12      21043.39      False
# 6      1     1  2010-03-19      22136.64      False
# 7      1     1  2010-03-26      26229.21      False

# %%
# check to see if 'train' and 'test' dataframes has 'Date' type to convert
pd.DataFrame({'Type_Train': train.dtypes, 'Type_Test': test.dtypes})
# Out:
#              Type_Train Type_Test
# Date             object    object
# Dept              int64     int64
# IsHoliday          bool      bool
# Store             int64     int64
# Weekly_Sales    float64       NaN

# %%
features_store.Date = pd.to_datetime(features_store.Date)
train.Date = pd.to_datetime(train.Date)
test.Date = pd.to_datetime(test.Date)

# %%
# Date field represent each week, ending every friday.
#create a 'Week'  and  'Year' field
features_store['Week'] = features_store.Date.dt.week 
features_store['Year'] = features_store.Date.dt.year

# %%
#create two new dataframes 'train_new_details' and 'test_new_details' 
#containing all the information needed 
#join 'train' and 'test' with 'features_store'
#keys are 'Store', 'Dept' and 'IsHoliday'.
train_new_details = train.merge(features_store,
                     how='inner',
                     on=['Store','Date','IsHoliday']).sort_values(by=['Store','Dept','Date']).reset_index(drop=True)

# %%
test_new_details = test.merge(features_store, 
                           how='inner', 
                           on=['Store','Date','IsHoliday']).sort_values(by=['Store','Dept','Date']).reset_index(drop=True)

# %%
del features, train, stores, test

# %%
#search for null values for each column.
null_columns = (train_new_details.isnull().sum(axis = 0)/len(train_new_details)).sort_values(ascending=False).index
null_data = pd.concat([
    train_new_details.isnull().sum(axis = 0),
    (train_new_details.isnull().sum(axis = 0)/len(train_new_details)).sort_values(ascending=False),
    train_new_details.loc[:, train_new_details.columns.isin(list(null_columns))].dtypes], axis=1)
null_data = null_data.rename(columns={0: '# null', 
                                      1: '% null', 
                                      2: 'type'}).sort_values(ascending=False, by = '% null')
null_data = null_data[null_data["# null"]!=0]
null_data
# Out:
#            # null    % null     type
# MarkDown2  310322  0.736110  float64
# MarkDown4  286603  0.679847  float64
# MarkDown3  284479  0.674808  float64
# MarkDown1  270889  0.642572  float64
# MarkDown5  270138  0.640790  float64

# %%
#Holidays Analysis to find out the week days that the Holidays fall on each year
